# %%
# 1
import numpy as np
import matplotlib.pyplot as plt

f_inv = lambda y: np.log(1+y)

uni = np.random.uniform(size=1000)

samples = [f_inv(i) for i in uni]

plt.scatter(samples, uni)

# %%
p_prop = lambda x: 1.5*x
p_x = lambda x:

smples = []

uniform_smples = np.random.uniform(1000)

for i in uniform_smples:
